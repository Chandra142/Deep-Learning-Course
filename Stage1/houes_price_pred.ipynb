# %%
import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.datasets import boston_housing

# %% [markdown]
# STEPS TO TRAIN THE DEEPL MODEL
# # 1.Sequential
# # 2.compile/preprocess
# # 3.fit

# %%
(x_train,y_train),(x_test, y_test) = (boston_housing.load_data())

# %%
len(x_train[0])
# Out:
# 13

# %% [markdown]
# Dense are using to create a hidden layers in cnn

# %%
model = Sequential()
model.add(Dense(20,activation= "relu", input_shape = (13,)))
model.add(Dense(15,activation="tanh"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1))

# %%
model.compile(optimizer="Adam",loss = "mse",metrics = ["mae"])

# %%
#after data collections
#use preprocessor data

mean = x_train.mean(axis = 0)
std_ = x_train.std(axis = 0)

# %%
#now data is standardise

x_train = x_train/std_
x_test = x_test/std_

# %%
model.fit (
    x_train,
    y_train,
    epochs=20,
    batch_size=4,
    validation_split=0.10,
    verbose=1
)
# Out:
# Epoch 1/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 592.4836 - mae: 22.4288 - val_loss: 472.2025 - val_mae: 20.7249
# Epoch 2/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 540.4513 - mae: 21.2400 - val_loss: 437.3489 - val_mae: 19.8662
# Epoch 3/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 511.4229 - mae: 20.5506 - val_loss: 415.2062 - val_mae: 19.3009
# Epoch 4/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 490.3258 - mae: 20.0209 - val_loss: 395.1184 - val_mae: 18.7733
# Epoch 5/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 467.8020 - mae: 19.4480 - val_loss: 373.3028 - val_mae: 18.1830
# Epoch 6/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 446.2915 - mae: 18.8954 - val_loss: 354.2845 - val_mae: 17.6523
# Epoch 7/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 427.2786 - mae: 18.3838 - val_loss: 337.1635 - val_mae: 17.1605
# Epoch 8/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 408.7830 - mae: 17.8766 - val_loss: 317.1899 - val_mae: 16.5683
# Epoch 9/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 382.2855 - mae: 17.1072 - val_loss: 290.6472 - val_mae: 15.7470
# Epoch 10/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 357.9951 - mae: 16.4078 - val_loss: 269.9827 - val_mae: 15.0766
# Epoch 11/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 333.7828 - mae: 15.6571 - val_loss: 244.5979 - val_mae: 14.2249
# Epoch 12/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 308.5947 - mae: 14.8386 - val_loss: 223.9142 - val_mae: 13.5139
# Epoch 13/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 288.3660 - mae: 14.1653 - val_loss: 206.4664 - val_mae: 12.8819
# Epoch 14/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 270.7926 - mae: 13.5743 - val_loss: 191.4177 - val_mae: 12.3092
# Epoch 15/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 255.1530 - mae: 13.0326 - val_loss: 177.4832 - val_mae: 11.7524
# Epoch 16/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 240.8707 - mae: 12.5068 - val_loss: 165.0738 - val_mae: 11.2345
# Epoch 17/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 227.8736 - mae: 12.0097 - val_loss: 153.5761 - val_mae: 10.7540
# Epoch 18/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 215.9432 - mae: 11.5499 - val_loss: 143.0335 - val_mae: 10.2910
# Epoch 19/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 204.8629 - mae: 11.1259 - val_loss: 133.6146 - val_mae: 9.8653
# Epoch 20/20
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 194.6211 - mae: 10.7214 - val_loss: 124.6064 - val_mae: 9.4516

# %%
mse_loss, mae_loss = model.evaluate(x_test,y_test)
print(mse_loss)
print(mae_loss)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 195.8214 - mae: 11.4544
# 195.82144165039062
# 11.45437240600586

# %%
y_pred = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
y_pred[0]
# Out:
# array([12.46817], dtype=float32)

# %%
y_test[0]
# Out:
# np.float64(7.2)

# %%
#final step 
#saving model
keras.models.save_model(model,"boston_houese_pred.keras")

# %%
m1 = keras.models.load_model("boston_houese_pred.keras")

# %%
m1.predict(x_test[0].reshape(1,13))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# array([[14.398242]], dtype=float32)

# %%
print(y_test[0])
# Out:
# 7.2
